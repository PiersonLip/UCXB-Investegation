# %%
import pandas as pd
from pathlib import Path

from posydon.popsyn.binarypopulation import BinaryPopulation
from posydon.binary_evol.binarystar import BinaryStar
from posydon.binary_evol.singlestar import SingleStar
from posydon.popsyn.synthetic_population import Population

import astropy.units as u

# %%
dataPath = Path('/home/bku2126/b1095/bku2126/UCXBInvestigation/Data').resolve()

(dataPath /'1e+00_Zsun_population_max.h5').resolve()
# Out:
# PosixPath('/gpfs/projects/b1095/bku2126/UCXBInvestigation/Data/1e+00_Zsun_population_max.h5')

# %%
loadedpop = Population('/home/bku2126/b1095/bku2126/UCXBInvestigation/Data/1e+00_Zsun_population_max.h5')
# Out:
# Missing ini parameter: orbital_separation_scheme
# Missing ini parameter: orbital_separation_min
# Missing ini parameter: orbital_separation_max

# %%
# loadedpop.ini_params

# %%
cols = ['time', 'step_names', 'state', 'event', 'S1_state', 'S2_state', 'S1_mass', 'S2_mass', 'orbital_period']
finCols = [
    'orbital_period_f',
    'eccentricity_f',
    'state_f',

    'S2_state_f',
    'S2_mass_f',
    'S2_log_R_f',

    'S1_state_f',
    'S1_mass_f',
    'S1_log_R_f'
 ]

initCols = [
    'orbital_period_i',
    'eccentricity_i',
    'state_i',

    'S2_state_i',
    'S2_mass_i',
    'S2_log_R_i',

    'S1_state_i',
    'S1_mass_i',
    'S1_log_R_i'
 ]

# %%
loadedpop.oneline[5][finCols]
# Out:
#               orbital_period_f  eccentricity_f   state_f S2_state_f  \
# binary_index
# 5                     0.215179         0.45703  detached         NS
#
#               S2_mass_f  S2_log_R_f S1_state_f  S1_mass_f  S1_log_R_f
# binary_index
# 5              1.357263   -4.745687         BH  10.248538   -4.361463

# %%
XrB_Logic = "((S2_state_f == 'BH') | (S2_state_f == 'NS')) & ((S1_state_f != 'BH') & (S1_state_f != 'NS')) | ((S1_state_f == 'BH') | (S1_state_f == 'NS')) & ((S2_state_f != 'BH') & (S2_state_f != 'NS')) &((state_f == 'initial_RLOF') | (state_f == 'RLO2') | (state_f == 'detached')) "

# %%
XB_Logic =

# %%
UCXB_Logic =  '(event == CO_contact) & (S1_state == BH) & (S2_state == BH)'

# %%
XrBs = loadedpop.oneline.select(where=XrB_Logic)

# %%
XrBs[finCols]['orbital_period_f'].describe()
# Out:
# count    4.442000e+04
# mean     2.082996e+05
# std      3.637993e+07
# min      7.339013e-03
# 25%      5.004272e+00
# 50%      2.061828e+01
# 75%      1.764903e+02
# max      7.641090e+09
# Name: orbital_period_f, dtype: float64

# %%
XrBs["state_f"].unique()
# Out:
# array(['initial_RLOF', 'detached', 'merged', 'RLO2'], dtype=object)

# %%
XrBs
# Out:
#                state_i event_i        time_i  orbital_period_i  \
# binary_index
# 7             detached    ZAMS  6.071461e+07          5.727203
# 58            detached    ZAMS  5.844620e+06        315.558057
# 70            detached    ZAMS  5.337287e+07        191.774235
# 89            detached    ZAMS  5.743554e+07         14.956130
# 97            detached    ZAMS  5.290663e+07         14.936797
# ...                ...     ...           ...               ...
# 999862        detached    ZAMS  3.429986e+07         18.847059
# 999887        detached    ZAMS  4.710015e+07         18.027537
# 999957        detached    ZAMS  8.870916e+07       1200.736652
# 999962        detached    ZAMS  4.700943e+07          4.781253
# 999993        detached    ZAMS  3.509691e+07       1940.147523
#
#               eccentricity_i  rl_relative_overflow_1_i  \
# binary_index
# 7                        0.0                       NaN
# 58                       0.0                       NaN
# 70                       0.0                       NaN
# 89                       0.0                       NaN
# 97                       0.0                       NaN
# ...                      ...                       ...
# 999862                   0.0                       NaN
# 999887                   0.0                       NaN
# 999957                   0.0                       NaN
# 999962                   0.0                       NaN
# 999993                   0.0                       NaN
#
#               rl_relative_overflow_2_i  lg_mtransfer_rate_i  \
# binary_index
# 7                                  NaN                  NaN
# 58                                 NaN                  NaN
# 70                                 NaN                  NaN
# 89                                 NaN                  NaN
# 97                                 NaN                  NaN
# ...                                ...                  ...
# 999862                             NaN                  NaN
# 999887                             NaN                  NaN
# 999957                             NaN                  NaN
# 999962                             NaN                  NaN
# 999993                             NaN                  NaN
#
#              mass_transfer_case_i  trap_radius_i  ...  \
# binary_index                                      ...
# 7                            None            NaN  ...
# 58                           None            NaN  ...
# 70                           None            NaN  ...
# 89                           None            NaN  ...
# 97                           None            NaN  ...
# ...                           ...            ...  ...
# 999862                       None            NaN  ...
# 999887                       None            NaN  ...
# 999957                       None            NaN  ...
# 999962                       None            NaN  ...
# 999993                       None            NaN  ...
#
#               interp_class_CO_HMS_RLO interp_class_CO_HeMS  \
# binary_index
# 7                         unstable_MT                  NaN
# 58                                NaN                  NaN
# 70                                NaN                  NaN
# 89                                NaN                  NaN
# 97                                NaN                  NaN
# ...                               ...                  ...
# 999862                            NaN                  NaN
# 999887                            NaN                  NaN
# 999957                            NaN                  NaN
# 999962                            NaN                  NaN
# 999993                            NaN                  NaN
#
#               interp_class_CO_HeMS_RLO                    mt_history_HMS_HMS  \
# binary_index
# 7                                  NaN             Stable RLOF during postMS
# 58                                 NaN             Stable RLOF during postMS
# 70                                 NaN             Stable RLOF during postMS
# 89                                 NaN             Stable RLOF during postMS
# 97                                 NaN   Stable RLOF during stripped He star
# ...                                ...                                   ...
# 999862                             NaN   Stable RLOF during stripped He star
# 999887                             NaN   Stable RLOF during stripped He star
# 999957                             NaN  Unstable reverse mass-transfer phase
# 999962                             NaN                Unstable contact phase
# 999993                             NaN           Unstable RLOF during postMS
#
#                 mt_history_CO_HMS_RLO  mt_history_CO_HeMS  \
# binary_index
# 7             Unstable RLOF during MS                 NaN
# 58                                NaN                 NaN
# 70                                NaN                 NaN
# 89                                NaN                 NaN
# 97                                NaN                 NaN
# ...                               ...                 ...
# 999862                            NaN                 NaN
# 999887                            NaN                 NaN
# 999957                            NaN                 NaN
# 999962                            NaN                 NaN
# 999993                            NaN                 NaN
#
#               mt_history_CO_HeMS_RLO  FAILED  WARNING  metallicity
# binary_index
# 7                                NaN       0        0          1.0
# 58                               NaN       0        0          1.0
# 70                               NaN       0        0          1.0
# 89                               NaN       0        0          1.0
# 97                               NaN       0        0          1.0
# ...                              ...     ...      ...          ...
# 999862                           NaN       0        0          1.0
# 999887                           NaN       0        0          1.0
# 999957                           NaN       0        1          1.0
# 999962                           NaN       0        1          1.0
# 999993                           NaN       0        1          1.0
#
# [52144 rows x 193 columns]

# %% [markdown]
# Assuming 'orbtial_period' is in days

# %%
orbitalPeriodMax = 120 * u.minute
OP_Max_val = orbitalPeriodMax.to(u.day).value

# %%
OP_Max_val
# Out:
# 0.08333333333333334

# %%
UCXBs = XrBs[XrBs['orbital_period_f'] < OP_Max_val]

# %%
UCXBs[finCols]
# Out:
#               orbital_period_f  eccentricity_f   state_f  \
# binary_index
# 1655                  0.047520             0.0  detached
# 5671                  0.042988             0.0  detached
# 6539                  0.021737             0.0  detached
# 7736                  0.042344             0.0  detached
# 9391                  0.032922             0.0      RLO2
# ...                        ...             ...       ...
# 996458                0.049732             0.0  detached
# 996770                0.036318             0.0  detached
# 997129                0.038433             0.0      RLO2
# 997431                0.037567             0.0      RLO2
# 998971                0.039462             0.0      RLO2
#
#                                    S2_state_f  S2_mass_f  S2_log_R_f  \
# binary_index
# 1655              stripped_He_Core_He_burning   1.002631   -0.671734
# 5671              stripped_He_Core_He_burning   0.995752   -0.645695
# 6539          stripped_He_Central_He_depleted   0.588549   -1.734909
# 7736              stripped_He_Core_He_burning   0.994781   -0.642391
# 9391          stripped_He_Central_He_depleted   0.629272   -0.765929
# ...                                       ...        ...         ...
# 996458            stripped_He_Core_He_burning   1.005995   -0.685923
# 996770            stripped_He_Core_He_burning   0.798373   -0.706517
# 997129            stripped_He_Core_He_burning   0.821736   -0.678814
# 997431            stripped_He_Core_He_burning   0.801076   -0.689222
# 998971            stripped_He_Core_He_burning   0.885196   -0.658285
#
#              S1_state_f  S1_mass_f  S1_log_R_f
# binary_index
# 1655                 NS   1.196033   -4.745687
# 5671                 NS   1.196033   -4.745687
# 6539                 NS   1.447240   -4.745687
# 7736                 NS   1.196033   -4.745687
# 9391                 NS   1.426753   -4.745687
# ...                 ...        ...         ...
# 996458               NS   1.196033   -4.745687
# 996770               NS   1.365607   -4.745687
# 997129               NS   1.350696   -4.745687
# 997431               NS   1.364058   -4.745687
# 998971               NS   1.291378   -4.745687
#
# [414 rows x 9 columns]

# %%
UCXBs[initCols]
# Out:
#               orbital_period_i  eccentricity_i   state_i  \
# binary_index
# 9391                658.896817             0.0  detached
# 27804               110.550073             0.0  detached
# 33205                63.519339             0.0  detached
# 34735               144.208059             0.0  detached
# 35903               366.371799             0.0  detached
# ...                        ...             ...       ...
# 990334              160.581317             0.0  detached
# 992327               71.963743             0.0  detached
# 997129              100.013230             0.0  detached
# 997431               94.178984             0.0  detached
# 998971              243.959453             0.0  detached
#
#                          S2_state_i  S2_mass_i  S2_log_R_i  \
# binary_index
# 9391          H-rich_Core_H_burning   6.282489         NaN
# 27804         H-rich_Core_H_burning   5.528905         NaN
# 33205         H-rich_Core_H_burning   6.932045         NaN
# 34735         H-rich_Core_H_burning   5.663441         NaN
# 35903         H-rich_Core_H_burning   5.825516         NaN
# ...                             ...        ...         ...
# 990334        H-rich_Core_H_burning   6.467172         NaN
# 992327        H-rich_Core_H_burning   6.461657         NaN
# 997129        H-rich_Core_H_burning   5.948707         NaN
# 997431        H-rich_Core_H_burning   6.033732         NaN
# 998971        H-rich_Core_H_burning   6.394167         NaN
#
#                          S1_state_i  S1_mass_i  S1_log_R_i
# binary_index
# 9391          H-rich_Core_H_burning   7.218872         NaN
# 27804         H-rich_Core_H_burning   8.169160         NaN
# 33205         H-rich_Core_H_burning   8.083295         NaN
# 34735         H-rich_Core_H_burning   7.812589         NaN
# 35903         H-rich_Core_H_burning   8.289445         NaN
# ...                             ...        ...         ...
# 990334        H-rich_Core_H_burning   7.233493         NaN
# 992327        H-rich_Core_H_burning   8.233295         NaN
# 997129        H-rich_Core_H_burning   7.776017         NaN
# 997431        H-rich_Core_H_burning   7.496448         NaN
# 998971        H-rich_Core_H_burning   7.634108         NaN
#
# [175 rows x 9 columns]

# %%
UCXBs.columns.tolist()
# Out:
# ['state_i',
#  'event_i',
#  'time_i',
#  'orbital_period_i',
#  'eccentricity_i',
#  'rl_relative_overflow_1_i',
#  'rl_relative_overflow_2_i',
#  'lg_mtransfer_rate_i',
#  'mass_transfer_case_i',
#  'trap_radius_i',
#  'acc_radius_i',
#  'step_names_i',
#  'step_times_i',
#  'state_f',
#  'event_f',
#  'time_f',
#  'orbital_period_f',
#  'eccentricity_f',
#  'rl_relative_overflow_1_f',
#  'rl_relative_overflow_2_f',
#  'lg_mtransfer_rate_f',
#  'mass_transfer_case_f',
#  'trap_radius_f',
#  'acc_radius_f',
#  'step_names_f',
#  'step_times_f',
#  'S1_state_i',
#  'S1_mass_i',
#  'S1_log_R_i',
#  'S1_log_L_i',
#  'S1_lg_mdot_i',
#  'S1_he_core_mass_i',
#  'S1_he_core_radius_i',
#  'S1_co_core_mass_i',
#  'S1_co_core_radius_i',
#  'S1_center_h1_i',
#  'S1_center_he4_i',
#  'S1_center_c12_i',
#  'S1_center_n14_i',
#  'S1_center_o16_i',
#  'S1_surface_h1_i',
#  'S1_surface_he4_i',
#  'S1_surface_c12_i',
#  'S1_surface_n14_i',
#  'S1_surface_o16_i',
#  'S1_log_LH_i',
#  'S1_log_LHe_i',
#  'S1_log_LZ_i',
#  'S1_log_Lnuc_i',
#  'S1_center_gamma_i',
#  'S1_avg_c_in_c_core_i',
#  'S1_surf_avg_omega_i',
#  'S1_surf_avg_omega_div_omega_crit_i',
#  'S1_total_moment_of_inertia_i',
#  'S1_log_total_angular_momentum_i',
#  'S1_spin_i',
#  'S1_envelope_binding_energy_i',
#  'S1_lambda_CE_1cent_i',
#  'S1_lambda_CE_10cent_i',
#  'S1_lambda_CE_30cent_i',
#  'S1_lambda_CE_pure_He_star_10cent_i',
#  'S1_state_f',
#  'S1_mass_f',
#  'S1_log_R_f',
#  'S1_log_L_f',
#  'S1_lg_mdot_f',
#  'S1_he_core_mass_f',
#  'S1_he_core_radius_f',
#  'S1_co_core_mass_f',
#  'S1_co_core_radius_f',
#  'S1_center_h1_f',
#  'S1_center_he4_f',
#  'S1_center_c12_f',
#  'S1_center_n14_f',
#  'S1_center_o16_f',
#  'S1_surface_h1_f',
#  'S1_surface_he4_f',
#  'S1_surface_c12_f',
#  'S1_surface_n14_f',
#  'S1_surface_o16_f',
#  'S1_log_LH_f',
#  'S1_log_LHe_f',
#  'S1_log_LZ_f',
#  'S1_log_Lnuc_f',
#  'S1_center_gamma_f',
#  'S1_avg_c_in_c_core_f',
#  'S1_surf_avg_omega_f',
#  'S1_surf_avg_omega_div_omega_crit_f',
#  'S1_total_moment_of_inertia_f',
#  'S1_log_total_angular_momentum_f',
#  'S1_spin_f',
#  'S1_envelope_binding_energy_f',
#  'S1_lambda_CE_1cent_f',
#  'S1_lambda_CE_10cent_f',
#  'S1_lambda_CE_30cent_f',
#  'S1_lambda_CE_pure_He_star_10cent_f',
#  'S1_natal_kick_array_0',
#  'S1_natal_kick_array_1',
#  'S1_natal_kick_array_2',
#  'S1_natal_kick_array_3',
#  'S1_SN_type',
#  'S1_f_fb',
#  'S1_spin_orbit_tilt_first_SN',
#  'S1_spin_orbit_tilt_second_SN',
#  'S2_state_i',
#  'S2_mass_i',
#  'S2_log_R_i',
#  'S2_log_L_i',
#  'S2_lg_mdot_i',
#  'S2_he_core_mass_i',
#  'S2_he_core_radius_i',
#  'S2_co_core_mass_i',
#  'S2_co_core_radius_i',
#  'S2_center_h1_i',
#  'S2_center_he4_i',
#  'S2_center_c12_i',
#  'S2_center_n14_i',
#  'S2_center_o16_i',
#  'S2_surface_h1_i',
#  'S2_surface_he4_i',
#  'S2_surface_c12_i',
#  'S2_surface_n14_i',
#  'S2_surface_o16_i',
#  'S2_log_LH_i',
#  'S2_log_LHe_i',
#  'S2_log_LZ_i',
#  'S2_log_Lnuc_i',
#  'S2_center_gamma_i',
#  'S2_avg_c_in_c_core_i',
#  'S2_surf_avg_omega_i',
#  'S2_surf_avg_omega_div_omega_crit_i',
#  'S2_total_moment_of_inertia_i',
#  'S2_log_total_angular_momentum_i',
#  'S2_spin_i',
#  'S2_envelope_binding_energy_i',
#  'S2_lambda_CE_1cent_i',
#  'S2_lambda_CE_10cent_i',
#  'S2_lambda_CE_30cent_i',
#  'S2_lambda_CE_pure_He_star_10cent_i',
#  'S2_state_f',
#  'S2_mass_f',
#  'S2_log_R_f',
#  'S2_log_L_f',
#  'S2_lg_mdot_f',
#  'S2_he_core_mass_f',
#  'S2_he_core_radius_f',
#  'S2_co_core_mass_f',
#  'S2_co_core_radius_f',
#  'S2_center_h1_f',
#  'S2_center_he4_f',
#  'S2_center_c12_f',
#  'S2_center_n14_f',
#  'S2_center_o16_f',
#  'S2_surface_h1_f',
#  'S2_surface_he4_f',
#  'S2_surface_c12_f',
#  'S2_surface_n14_f',
#  'S2_surface_o16_f',
#  'S2_log_LH_f',
#  'S2_log_LHe_f',
#  'S2_log_LZ_f',
#  'S2_log_Lnuc_f',
#  'S2_center_gamma_f',
#  'S2_avg_c_in_c_core_f',
#  'S2_surf_avg_omega_f',
#  'S2_surf_avg_omega_div_omega_crit_f',
#  'S2_total_moment_of_inertia_f',
#  'S2_log_total_angular_momentum_f',
#  'S2_spin_f',
#  'S2_envelope_binding_energy_f',
#  'S2_lambda_CE_1cent_f',
#  'S2_lambda_CE_10cent_f',
#  'S2_lambda_CE_30cent_f',
#  'S2_lambda_CE_pure_He_star_10cent_f',
#  'S2_natal_kick_array_0',
#  'S2_natal_kick_array_1',
#  'S2_natal_kick_array_2',
#  'S2_natal_kick_array_3',
#  'S2_SN_type',
#  'S2_f_fb',
#  'S2_spin_orbit_tilt_first_SN',
#  'S2_spin_orbit_tilt_second_SN',
#  'interp_class_HMS_HMS',
#  'interp_class_CO_HMS_RLO',
#  'interp_class_CO_HeMS',
#  'interp_class_CO_HeMS_RLO',
#  'mt_history_HMS_HMS',
#  'mt_history_CO_HMS_RLO',
#  'mt_history_CO_HeMS',
#  'mt_history_CO_HeMS_RLO',
#  'FAILED',
#  'WARNING',
#  'metallicity']

# %%
def quickAnalysis(df):
    print(df['S1_mass_i'].describe())
    print(df['S2_mass_i'].describe())
    print(df['eccentricity_f'].describe())
    print(df['S1_state_f'].unique())
    print(df['S2_state_f'].unique())

# %%
Old_UCXB = pd.read_csv('UCXBs.csv')

# %%
Old_UCXB['S1_state'].unique()
# Out:
# array(['NS'], dtype=object)

# %%
quickAnalysis(UCXBs)
# Out:
# count    414.000000
# mean       7.752548
# std        0.633605
# min        7.000129
# 25%        7.426302
# 50%        7.711382
# 75%        8.032036
# max       14.392558
# Name: S1_mass_i, dtype: float64
# count    414.000000
# mean       6.073793
# std        0.575187
# min        4.615856
# 25%        5.689916
# 50%        6.147197
# 75%        6.505637
# max        7.383596
# Name: S2_mass_i, dtype: float64
# count    414.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: eccentricity_f, dtype: float64
# ['NS']
# ['stripped_He_Core_He_burning' 'stripped_He_Central_He_depleted' 'WD']
