# %%
import pandas as pd
from pathlib import Path

from posydon.popsyn.binarypopulation import BinaryPopulation
from posydon.binary_evol.binarystar import BinaryStar
from posydon.binary_evol.singlestar import SingleStar
from posydon.popsyn.synthetic_population import Population
from posydon.popsyn.synthetic_population import PopulationRunner
import astropy.units as u

import os
import shutil
from posydon.config import PATH_TO_POSYDON

# %%
print(PATH_TO_POSYDON)
# Out:
# /home/bku2126/b1095/bku2126/UCXBInvestigation/POSYDON

# %%
loadedpop = Population('/home/bku2126/b1095/bku2126/UCXBInvestigation/Project/InitResearch/1e+00_Zsun_population.h5')

# %%
cols = ['time', 'step_names', 'state', 'event', 'S1_state', 'S2_state', 'S1_mass', 'S2_mass', 'orbital_period']
finCols = [
    'orbital_period_f',
    'eccentricity_f',
    'state_f',

    'S2_state_f',
    'S2_mass_f',
    'S2_log_R_f',

    'S1_state_f',
    'S1_mass_f',
    'S1_log_R_f'
 ]

initCols = [
    'orbital_period_i',
    'eccentricity_i',
    'state_i',

    'S2_state_i',
    'S2_mass_i',
    'S2_log_R_i',

    'S1_state_i',
    'S1_mass_i',
    'S1_log_R_i'
 ]

# %%
XrB_Logic = "((S2_state_f == 'BH') | (S2_state_f == 'NS')) & ((S1_state_f != 'BH') & (S1_state_f != 'NS')) | ((S1_state_f == 'BH') | (S1_state_f == 'NS')) & ((S2_state_f != 'BH') & (S2_state_f != 'NS')) &((state_f == 'initial_RLOF') | (state_f == 'RLO2') | (state_f == 'detached')) "

# %%
XrBs = loadedpop.oneline.select(where=XrB_Logic)

# %%
orbitalPeriodMax = 120 * u.minute
OP_Max_val = orbitalPeriodMax.to(u.day).value
UCXBs = XrBs[XrBs['orbital_period_f'] < OP_Max_val]

# %%
UCXBs[finCols]
# Out:
#               orbital_period_f  eccentricity_f       state_f  \
# binary_index
# 160                   0.037378             0.0  initial_RLOF
# 934                   0.039452             0.0  initial_RLOF
#
#                            S2_state_f  S2_mass_f  S2_log_R_f S1_state_f  \
# binary_index
# 160           stripped_He_non_burning   1.196209   -0.680462         NS
# 934           stripped_He_non_burning   0.992711   -0.731126         NS
#
#               S1_mass_f  S1_log_R_f
# binary_index
# 160            1.268177   -4.745687
# 934            1.265101   -4.745687
